# %% [markdown]
# # Convolutional Neural Network

# %%
import pandas as pd
from finlab.data import Data
data = Data()
twii = data.get("發行量加權股價指數")
twii = twii['台股指數']
twii = twii.resample('15T').first().dropna() #每15分鐘取樣第一個收盤價

# %% [markdown]
# ## 製作features

# %%
import numpy as np
import tqdm
time_period = 200

#由於cnn可以額外加入時間序列的資訊，因此我們可以直接將時間序列的資料丟進去
cnn_x = []
cnn_y = []
indexs = []
for i in tqdm.tqdm_notebook(range(0, len(twii) - time_period - 1 - 11, 3)):
    s = twii.iloc[i:i+time_period].values
    cnn_x.append((s - s.min())/(s.max() - s.min())) #normalize
    r = twii.iloc[i+time_period+10] / twii.iloc[i+time_period-1]
    cnn_y.append(r)
    indexs.append(twii.index[i+time_period-1])

cnn_x = np.array(cnn_x)
cnn_y = np.array(cnn_y)
indexes = np.array(indexs)
# Out:
# C:\Users\jerry\AppData\Local\Temp\ipykernel_4384\2692381262.py:9: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm.tqdm_notebook(range(0, len(twii) - time_period - 1 - 11, 3)):
#   0%|          | 0/25960 [00:00<?, ?it/s]

# %% [markdown]
# ## Reshape features and labels

# %%
import matplotlib.pyplot as plt

plt.plot(cnn_x[0])
print(cnn_y[0])
# Out:
# 1.0115834671246686

# %%
cnn_x = cnn_x.reshape(len(cnn_x), time_period, 1)
cnn_y = cnn_y.reshape(len(cnn_y), 1)

# %% [markdown]
# ## Split traning and testing data

# %%
import datetime
cnn_x_train = cnn_x[indexes < datetime.datetime(2016,1,1)]
cnn_y_train = cnn_y[indexes < datetime.datetime(2016,1,1)]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(cnn_x[0].reshape(1, len(cnn_x[0]))[0])

# %% [markdown]
# ## CNN

# %%
from tensorflow import keras
from tensorflow.keras import layers

input_shape = cnn_x[0].shape
time_period = 200
num_classes = 1

model = keras.Sequential() #建立一個序列模型

model.add(layers.Conv1D(filters=20, kernel_size=20, activation='relu', input_shape=cnn_x[0].shape))
model.add(layers.AveragePooling1D(5)) #將長度為5的區間取平均

model.add(layers.Conv1D(filters=20, kernel_size=20, activation='relu'))
model.add(layers.AveragePooling1D(5))
model.add(layers.Flatten())
model.add(layers.Dense(units=120, activation='relu'))
model.add(layers.Dense(units=84, activation='relu'))
model.add(layers.Dense(units=1, ))#activation = 'softmax'))

adam = keras.optimizers.Adam(lr=0.0005, beta_1=0.9, beta_2=0.99, epsilon=None, decay=0.01, amsgrad=False)

model.compile(loss='mse',
                optimizer=adam)

print(model.summary())

history = model.fit(cnn_x_train, cnn_y_train,
                    batch_size=200,
                    epochs=50,
                    verbose=1,
                    validation_split=0.1, )
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 181, 20)           420
#
#  average_pooling1d (AverageP  (None, 36, 20)           0
#  ooling1D)
#
#  conv1d_1 (Conv1D)           (None, 17, 20)            8020
#
#  average_pooling1d_1 (Averag  (None, 3, 20)            0
#  ePooling1D)
#
#  flatten (Flatten)           (None, 60)                0
#
#  dense (Dense)               (None, 120)               7320
#
#  dense_1 (Dense)             (None, 84)                10164
#
#  dense_2 (Dense)             (None, 1)                 85
#
# =================================================================
# Total params: 26,009
# Trainable params: 26,009
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# d:\Anaconda\envs\fintech2\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 71/71 [==============================] - 8s 6ms/step - loss: 0.1801 - val_loss: 0.0203
# Epoch 2/50
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0078 - val_loss: 0.0046
# Epoch 3/50
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 4/50
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 5/50
# 71/71 [==============================] - 0s 3ms/step - loss: 6.8911e-04 - val_loss: 8.4342e-04
# Epoch 6/50
# 71/71 [==============================] - 0s 3ms/step - loss: 4.9556e-04 - val_loss: 6.8117e-04
# Epoch 7/50
# 71/71 [==============================] - 0s 4ms/step - loss: 3.8748e-04 - val_loss: 5.4324e-04
# Epoch 8/50
# 71/71 [==============================] - 0s 3ms/step - loss: 2.9724e-04 - val_loss: 3.8095e-04
# Epoch 9/50
# 71/71 [==============================] - 0s 3ms/step - loss: 2.3042e-04 - val_loss: 2.5474e-04
# Epoch 10/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.9286e-04 - val_loss: 2.0493e-04
# Epoch 11/50
# 71/71 [==============================] - 0s 4ms/step - loss: 1.6790e-04 - val_loss: 2.1618e-04
# Epoch 12/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.5149e-04 - val_loss: 1.4069e-04
# Epoch 13/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.4182e-04 - val_loss: 1.2379e-04
# Epoch 14/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.3145e-04 - val_loss: 1.1773e-04
# Epoch 15/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.2851e-04 - val_loss: 1.0721e-04
# Epoch 16/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.2434e-04 - val_loss: 1.0577e-04
# Epoch 17/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.2260e-04 - val_loss: 9.4155e-05
# Epoch 18/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.1891e-04 - val_loss: 8.9326e-05
# Epoch 19/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.1856e-04 - val_loss: 8.4882e-05
# Epoch 20/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.1521e-04 - val_loss: 8.4895e-05
# Epoch 21/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.1411e-04 - val_loss: 8.9629e-05
# Epoch 22/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.1328e-04 - val_loss: 9.8876e-05
# Epoch 23/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.1343e-04 - val_loss: 8.1113e-05
# Epoch 24/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.1184e-04 - val_loss: 8.5368e-05
# Epoch 25/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.1299e-04 - val_loss: 7.9195e-05
# Epoch 26/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.1111e-04 - val_loss: 8.0129e-05
# Epoch 27/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.1185e-04 - val_loss: 7.7809e-05
# Epoch 28/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.0904e-04 - val_loss: 9.0327e-05
# Epoch 29/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.0851e-04 - val_loss: 7.7879e-05
# Epoch 30/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.0830e-04 - val_loss: 7.5151e-05
# Epoch 31/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.0903e-04 - val_loss: 7.4271e-05
# Epoch 32/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.0749e-04 - val_loss: 9.3861e-05
# Epoch 33/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.0866e-04 - val_loss: 8.0516e-05
# Epoch 34/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.0749e-04 - val_loss: 7.4387e-05
# Epoch 35/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.0665e-04 - val_loss: 7.2819e-05
# Epoch 36/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.0565e-04 - val_loss: 7.6530e-05
# Epoch 37/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.0519e-04 - val_loss: 7.0868e-05
# Epoch 38/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.0670e-04 - val_loss: 7.3746e-05
# Epoch 39/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.0507e-04 - val_loss: 7.7924e-05
# Epoch 40/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.0499e-04 - val_loss: 6.9942e-05
# Epoch 41/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.0529e-04 - val_loss: 7.2879e-05
# Epoch 42/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.0425e-04 - val_loss: 7.3928e-05
# Epoch 43/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.0457e-04 - val_loss: 6.8688e-05
# Epoch 44/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.0391e-04 - val_loss: 7.3988e-05
# Epoch 45/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.0408e-04 - val_loss: 6.8461e-05
# Epoch 46/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.0288e-04 - val_loss: 6.8779e-05
# Epoch 47/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.0323e-04 - val_loss: 6.9003e-05
# Epoch 48/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.0406e-04 - val_loss: 7.3949e-05
# Epoch 49/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.0421e-04 - val_loss: 7.4765e-05
# Epoch 50/50
# 71/71 [==============================] - 0s 3ms/step - loss: 1.0215e-04 - val_loss: 6.8118e-05

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(np.log(history.history['loss'][1:]))
plt.plot(np.log(history.history['val_loss']))

# %%
ey = model.predict(cnn_x)
ey = pd.Series(ey.swapaxes(0, 1)[0], index=indexes)
# Out:
# 812/812 [==============================] - 1s 942us/step

# %%
eq = twii[pd.to_datetime(indexes)]
gain = (eq.shift(-1) - eq)

signal = (ey > ey.quantile(0.9)).rolling(20).sum() > 0
eq = (gain[signal])['2016':].cumsum()
eq.plot()
# Out:
# <Axes: >

# %%
signal['2016':].astype(int).diff().abs().sum()
# Out:
# 185.0
